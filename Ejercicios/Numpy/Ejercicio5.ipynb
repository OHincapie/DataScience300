# %% [markdown]
# <a href="https://colab.research.google.com/github/OHincapie/DataScience300/blob/main/Ejercicios/Numpy/Ejercicio5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio 5
#
# Carguen la imagen data_science que se encuentra en el siguiente link: [texto del enlace](https://drive.google.com/file/d/1LoGybQ8t9g6orVp8Wh0uqU7BXY0kCzlh/view?usp=sharing) en la semana 1 del Bootcamp y realicen los siguientes procedimientos
#
# 1. Muestrar la imagen tal como viene
# 2. Averiguen que es un pixel y determinen cuantos pixeles tiene la imagen
# 3. Recortar la imagen donde solo aparezca la palabra DATA
# 4. Convertir la imagen a matriz y aplicar la funcion coseno
# 5. Reemplazar los valores menores que 100 en la imagen original por 180 y graficar ¿Que observan, que modificaciones ocurrieron y porque?. **Sugerencia:** *Busquen acerca de que es la escala RGB y seguro comprenderan mejor*

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
print(os.getcwd())
#os.chdir("/content/gdrive/MyDrive")
print(os.getcwd())
# Out:
# /content
# /content

# %%
# %cd '/content/gdrive/MyDrive/Bootcamp/Semana 1/'
# Out:
# /content/gdrive/MyDrive/Bootcamp/Semana 1

# %%
from skimage import io 
import matplotlib.pyplot as plt
import numpy as np

# %%
imagen = io.imread('/content/gdrive/MyDrive/Bootcamp/Semana 1/Copia de data_science.jpg')
print('Punto 1')
plt.imshow(imagen)
# Out:
# Punto 1

# %%
print('Punto 2')
print('Pixeles',imagen.shape)
# Out:
# Punto 2
# Pixeles (743, 1320, 3)

# %%
print('Punto 3')
plt.imshow(imagen[180:335,150:620,2])
# Out:
# Punto 3

# %%
print('Punto 4')
imagen_cos = np.cos(imagen)
print(imagen_cos)
# Out:
# Punto 4
# [[[-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   ...
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]]
#
#  [[-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   ...
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]]
#
#  [[-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   ...
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]]
#
#  ...
#
#  [[-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   ...
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]]
#
#  [[-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   ...
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]]
#
#  [[-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   ...
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]
#   [-0.858   0.2323 -0.4949]]]

# %%
print('Parte 5')
plt.imshow(np.where(imagen<100, 180, imagen))
# Out:
# Parte 5
